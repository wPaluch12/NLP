# %%
from collections import defaultdict
from os import listdir
from spacy.tokenizer import Tokenizer
from spacy.lang.pl import Polish
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
from nltk import ngrams
from numpy import log

# %% [markdown]
# ### Use SpaCy tokenizer API to tokenize the text from the law corpus.

# %%
nlp = Polish()
tokenizer = nlp.tokenizer

# %%
def get_freq_defaultdict(tokens):
    freq = defaultdict(int)
    for token in tokens:
        if token.text.isalpha():
            freq[token.text] += 1
    return freq

# %%
def get_freq_bigrams(tokens):
    freq = defaultdict(int)
    for token in tokens:
        if token[0].text.isalpha() and token[1].text.isalpha():
            freq[token[0].text+' '+token[1].text] += 1
    return freq

# %%
global_freq = defaultdict(int) #Aggregate the result to obtain one global frequency list.
global_bigrams = defaultdict(int)
tokens_global = []

for file in listdir("ustawy"):
    with open(f'ustawy/{file}', "r", encoding='utf-8') as f:
        content = f.read().lower()
        content = re.sub(r"\s+", " ", content)
        tokens = tokenizer(content)
        doc_freq = get_freq_defaultdict(tokens)
        [global_freq.update({word: global_freq[word]+doc_freq[word]}) for word in doc_freq]
        bigrams = [gram for gram in ngrams(tokens, 2)]
        doc_freq = get_freq_bigrams(bigrams)
        [global_bigrams.update({word: global_bigrams[word]+doc_freq[word]}) for word in doc_freq]

# %% [markdown]
# ### Use pointwise mutual information to compute the measure for all pairs of words.

# %%
bigram_list = []
pmi_list = []
for bigram in global_bigrams:
    bigram_list.append(bigram)
    word_a, word_b = bigram.split()
    pmi_list.append(log((global_bigrams[bigram])/len(global_freq)) - log((global_freq[word_a])/len(global_freq)) - log((global_freq[word_b])/len(global_freq)))

# %% [markdown]
# ### Sort the word pairs according to that measure in the descending order and determine top 10 entries.

# %%
df =pd.DataFrame({"bigram":bigram_list,"pmi":pmi_list})
df.sort_values(by="pmi",ascending=False)[:10].reset_index(drop=True)
# Out:
#                       bigram       pmi
# 0          pobierały zasiłek  7.747165
# 1       taksówkami osobowymi  7.747165
# 2        wagonach kolejowych  7.747165
# 3       rolniczej ustalonych  7.747165
# 4  zaopatrzenia emerytalnego  7.747165
# 5   dotyczących zaopatrzenia  7.747165
# 6            jednolity tekst  7.747165
# 7          opieki społecznej  7.747165
# 8          jakiej prowadzona  7.747165
# 9       unieważnienie numeru  7.747165

# %% [markdown]
# ### Filter bigrams with number of occurrences lower than 5. Determine top 10 entries for the remaining dataset (>=5 occurrences).

# %%
global_bigrams_filter = defaultdict(int)
for bigram in global_bigrams:
    if global_bigrams[bigram]>4:
        global_bigrams_filter.update({bigram: global_bigrams_filter[bigram]+global_bigrams[bigram]})

# %%
bigram_list = []
pmi_list = []
for bigram in global_bigrams_filter:
    bigram_list.append(bigram)
    word_a, word_b = bigram.split()
    pmi_list.append(log((global_bigrams[bigram])/len(global_freq)) - log((global_freq[word_a])/len(global_freq)) - log((global_freq[word_b])/len(global_freq)))
df =pd.DataFrame({"bigram":bigram_list,"pmi":pmi_list})
bigram_morf = df.sort_values(by="pmi",ascending=False)[:10].reset_index(drop=True) 
bigram_morf
# Out:
#                       bigram       pmi
# 0           nim następującym  6.137727
# 1         danej miejscowości  5.955405
# 2  ubezpieczenia społecznego  5.955405
# 3     kwartale kalendarzowym  5.801255
# 4             urząd skarbowy  5.801255
# 5              górną granicę  5.801255
# 6  rzeczypospolitej polskiej  5.773084
# 7         granicę pierwszego  5.618933
# 8      pierwszego przedziału  5.618933
# 9       odrębnymi przepisami  5.549940

# %%
bigram_list = []
pmi_list = []
for bigram in global_bigrams_filter:
    bigram_list.append(bigram)
    word_a, word_b = bigram.split()
    pmi_list.append(log((global_bigrams[bigram])/len(global_bigrams)) - log((global_freq[word_a])/len(global_bigrams)) - log((global_freq[word_b])/len(global_freq)))
df =pd.DataFrame({"bigram":bigram_list,"pmi":pmi_list})
df.sort_values(by="pmi",ascending=False)[:10].reset_index(drop=True)
# Out:
#                       bigram       pmi
# 0           nim następującym  6.137727
# 1  ubezpieczenia społecznego  5.955405
# 2         danej miejscowości  5.955405
# 3              górną granicę  5.801255
# 4     kwartale kalendarzowym  5.801255
# 5             urząd skarbowy  5.801255
# 6  rzeczypospolitej polskiej  5.773084
# 7      pierwszego przedziału  5.618933
# 8         granicę pierwszego  5.618933
# 9       odrębnymi przepisami  5.549940

# %% [markdown]
# ### Use Clarin-PL API(https://ws.clarin-pl.eu/tager.shtml) to tag and lemmatize the corpus. Using the tagged corpus compute bigram statistic for the tokens containing: a. lemmatized, downcased word b. morphosyntactic category of the word (subst, fin, adj, etc.)

# %%
def get_freq_xml(tokens):
    freq = defaultdict(int)
    for token in tokens:
        if token.split(':')[0].isalpha():
            freq[token] += 1
    return freq
def get_freq_bigrams_xml(tokens):
    freq = defaultdict(int)
    for token in tokens:
        if token[0].split(':')[0].isalpha() and token[1].split(':')[0].isalpha():
            freq[token[0]+' '+token[1]] += 1
    return freq

# %%
from xml.dom.minidom import parse

counter_dict = defaultdict(int)
counter_bigram = defaultdict(int)
word_dict = {}
for file in listdir("Wynik"):
    tokens=[]
    with open(f'Wynik/{file}', "r", encoding='utf-8') as f:
        doc = parse(f)
    for token in doc.getElementsByTagName("tok"):
        name = token.getElementsByTagName("orth")[0].firstChild.nodeValue.lower()
        base = token.getElementsByTagName("base")[0].firstChild.nodeValue.lower()
        tag = token.getElementsByTagName("ctag")[0].firstChild.nodeValue.split(':')[0].lower()
        word_dict[name] = {"base": base , "tag": tag}
        tokens.append(base+':'+tag)

    doc_freq = get_freq_xml(tokens)
    [counter_dict.update({word: counter_dict[word]+doc_freq[word]}) for word in doc_freq]
    bigrams = [gram for gram in ngrams(tokens, 2)]
    doc_freq = get_freq_bigrams_xml(bigrams)
    [counter_bigram.update({word: counter_bigram[word]+doc_freq[word]}) for word in doc_freq]

# %% [markdown]
# ### Compute the same statistics as for the non-lemmatized words (i.e. PMI) and print top-10 entries with at least 5 occurrences.

# %%
bigram_list = []
pmi_list = []
for bigram in counter_bigram:
    bigram_list.append(bigram)
    word_a, word_b = bigram.split()
    pmi_list.append(log((counter_bigram[bigram])/len(counter_dict)) - log((counter_dict[word_a])/len(counter_dict)) - log((counter_dict[word_b])/len(counter_dict)))
df =pd.DataFrame({"bigram":bigram_list,"pmi":pmi_list})
bigram_clarin = df.sort_values(by="pmi",ascending=False)[:10].reset_index(drop=True) 
bigram_clarin
# Out:
#                            bigram        pmi
# 0              eegcou:ign eok:ign  10.079036
# 1           poin:ign formować:inf  10.079036
# 2          kalen:ign darzowym:ign  10.079036
# 3             zajmo:ign wanym:ign  10.079036
# 4             mał:ign żonka:subst  10.079036
# 5          fomar:ign roulunds:ign  10.079036
# 6           ty:ppron12 godniu:ign  10.079036
# 7      uniemoż:ign liwiającej:ign  10.079036
# 8          krętek:subst blady:adj  10.079036
# 9  promować:inf nowatorstwo:subst  10.079036

# %% [markdown]
# ### Compute trigram counts for both corpora and perform the same filtering. Use PMI (with 5 occurrence threshold) to compute top 10 results for the trigrams. Devise a method for computing the values, based on the results for bigrams.

# %% [markdown]
# ##### corp 1

# %%
def get_freq_trigrams(tokens):
    freq = defaultdict(int)
    for token in tokens:
        if token[0].text.isalpha() and token[1].text.isalpha() and token[2].text.isalpha():
            freq[token[0].text+' '+token[1].text+' '+token[2].text] += 1
    freq_copy = freq.copy()
    for key in freq:
        if freq_copy[key]<5:
            del freq_copy[key]
            
    return freq_copy

# %%
# global_freq = defaultdict(int) #Aggregate the result to obtain one global frequency list.
global_trigrams = defaultdict(int)

for file in listdir("ustawy"):
    with open(f'ustawy/{file}', "r", encoding='utf-8') as f:
        content = f.read().lower()
        content = re.sub(r"\s+", " ", content)
        tokens = tokenizer(content)
        trigrams = [gram for gram in ngrams(tokens, 3)]
        doc_freq = get_freq_trigrams(trigrams)
        [global_trigrams.update({word: global_trigrams[word]+doc_freq[word]}) for word in doc_freq]

# %%
trigram_list = []
pmi_list = []
for trigram in global_trigrams:
#     print(trigram)
    trigram_list.append(trigram)
    word_a, word_b, word_c = trigram.split(" ")
    pmi_list.append(log((global_trigrams[trigram])/len(global_freq)) - log((global_freq[word_a])/len(global_freq)) - log((global_freq[word_b])/len(global_freq))- log((global_freq[word_c])/len(global_freq)))
 

df =pd.DataFrame({"trigram":trigram_list,"pmi":pmi_list})
trigram_morf = df.sort_values(by="pmi",ascending=False)[:10].reset_index(drop=True)
trigram_morf
# Out:
#                                  trigram        pmi
# 0               górną granicę pierwszego  11.574339
# 1  kwartale kalendarzowym poprzedzającym  11.245835
# 2    kalendarzowym poprzedzającym termin  11.112303
# 3      poprzedzającym termin waloryzacji  10.419156
# 4                    po nim następującym   9.807355
# 5                    nim następującym na   9.148694
# 6         rozumieniu odrębnych przepisów   8.460823
# 7                   następującym na cele   7.867760
# 8                 zwrotu różnicy podatku   7.615796
# 9                 z odrębnymi przepisami   7.535054

# %% [markdown]
# ##### corp 2

# %%
def get_freq_trigrams_xml(tokens):
    freq = defaultdict(int)
    for token in tokens:
        if token[0].split(':')[0].isalpha() and token[1].split(':')[0].isalpha() and token[2].split(':')[0].isalpha():
            freq[token[0]+' '+token[1]+' '+token[2]] += 1
    freq_copy = freq.copy()
    for key in freq:
        if freq_copy[key]<5:
            del freq_copy[key]
            
    return freq_copy

counter_trigram = defaultdict(int)
for file in listdir("Wynik"):
    tokens=[]
    with open(f'Wynik/{file}', "r", encoding='utf-8') as f:
        doc = parse(f)
    for token in doc.getElementsByTagName("tok"):
        name = token.getElementsByTagName("orth")[0].firstChild.nodeValue.lower()
        base = token.getElementsByTagName("base")[0].firstChild.nodeValue.lower()
        tag = token.getElementsByTagName("ctag")[0].firstChild.nodeValue.split(':')[0].lower()
        tokens.append(base+':'+tag)


    trigrams = [gram for gram in ngrams(tokens, 3)]
    doc_freq = get_freq_trigrams_xml(trigrams)
    [counter_trigram.update({word: counter_trigram[word]+doc_freq[word]}) for word in doc_freq]
counter_trigram
# Out:
# defaultdict(int,
#             {'o:prep służba:subst wojskowy:adj': 22,
#              'służba:subst wojskowy:adj żołnierz:subst': 38,
#              'wojskowy:adj żołnierz:subst zawodowy:adj': 31,
#              'do:prep zawodowy:adj służba:subst': 41,
#              'zawodowy:adj służba:subst wojskowy:adj': 377,
#              'służbowy:adj żołnierz:subst zawodowy:adj': 6,
#              'uposażenie:subst i:conj inny:subst': 29,
#              'i:conj inny:subst należność:subst': 26,
#              'inny:subst należność:subst pieniężny:adj': 23,
#              'przez:prep żołnierz:subst zawodowy:adj': 26,
#              'żołnierz:subst zawodowy:adj z:prep': 26,
#              'zawodowy:adj z:prep zawodowy:adj': 6,
#              'z:prep zawodowy:adj służba:subst': 139,
#              'kandydat:subst na:prep żołnierz:subst': 20,
#              'na:prep żołnierz:subst zawodowy:adj': 20,
#              'żołnierz:subst zawodowy:adj i:conj': 34,
#              'żołnierz:subst zawodowy:adj w:prep': 23,
#              'w:prep raz:subst ogłoszenie:subst': 36,
#              'raz:subst ogłoszenie:subst mobilizacja:subst': 36,
#              'stan:subst wojenny:adj i:conj': 33,
#              'wojenny:adj i:conj w:prep': 33,
#              'i:conj w:prep czas:subst': 35,
#              'w:prep czas:subst wojna:subst': 57,
#              'żołnierz:subst zawodowy:adj może:qub': 25,
#              'zawodowy:adj może:qub być:inf': 7,
#              'zdolność:subst fizyczny:adj i:conj': 18,
#              'fizyczny:adj i:conj psychiczny:adj': 24,
#              'i:conj psychiczny:adj do:prep': 10,
#              'do:prep pełnieć:ger zawodowy:adj': 20,
#              'pełnieć:ger zawodowy:adj służba:subst': 59,
#              'żołnierz:subst w:prep czynny:adj': 17,
#              'w:prep czynny:adj służba:subst': 19,
#              'czynny:adj służba:subst wojskowy:adj': 102,
#              'pełnia:subst zawodowy:adj służba:subst': 6,
#              'zawodowy:adj siła:subst zbrojny:adj': 12,
#              'siła:subst zbrojny:adj rzeczpospolita:subst': 39,
#              'zbrojny:adj rzeczpospolita:subst polski:adj': 39,
#              'korpus:subst oficer:subst zawodowy:adj': 6,
#              'korpus:subst podoficer:subst zawodowy:adj': 7,
#              'korpus:subst szeregowy:subst zawodowy:adj': 6,
#              'w:prep droga:subst rozporządzenie:subst': 4029,
#              'stanowisko:subst służbowy:adj w:prep': 34,
#              'korpus:subst kadr:subst zawodowy:adj': 10,
#              'kadr:subst zawodowy:adj siła:subst': 10,
#              'minister:subst obrona:subst narodowy:adj': 677,
#              'obrona:subst narodowy:adj określić:fin': 113,
#              'stanowisko:subst służbowy:adj oraz:conj': 5,
#              'wojskowy:adj komisja:subst lekarski:adj': 19,
#              'w:prep ten:adj sprawa:subst': 127,
#              'do:prep wojskowy:adj komisja:subst': 6,
#              'wykonywać:ger zadanie:subst służbowy:adj': 44,
#              'pozostawać:pact w:prep związek:subst': 5,
#              'w:prep związek:subst z:prep': 966,
#              'służba:subst wojskowy:adj lub:conj': 11,
#              'służba:subst wojskowy:adj poza:prep': 16,
#              'wojskowy:adj poza:prep granica:subst': 16,
#              'poza:prep granica:subst państwo:subst': 79,
#              'wymienić:ppas w:prep usta:subst': 263,
#              'uzasadniony:adj potrzeba:subst siła:subst': 7,
#              'potrzeba:subst siła:subst zbrojny:adj': 26,
#              'w:prep tym:conj w:prep': 48,
#              'wyznaczyć:ger na:prep stanowisko:subst': 26,
#              'na:prep stanowisko:subst służbowy:adj': 131,
#              'do:prep inny:subst korpus:subst': 6,
#              'inny:subst korpus:subst osobowy:subst': 6,
#              'zwolnienie:subst z:prep zawodowy:adj': 38,
#              'służba:subst wojskowy:adj z:prep': 9,
#              'z:prep wzgląd:subst na:prep': 724,
#              'osoba:subst ubiegać:pact się:qub': 63,
#              'ubiegać:pact się:qub o:prep': 177,
#              'o:prep powołanie:subst do:prep': 13,
#              'powołanie:subst do:prep zawodowy:adj': 11,
#              'dowódca:subst jednostka:subst wojskowy:adj': 110,
#              'w:prep przypadek:subst wymienić:ppas': 5,
#              'przypadek:subst wymienić:ppas w:prep': 5,
#              'organ:subst właściwy:adj do:prep': 200,
#              'wyznaczyć:ger żołnierz:subst zawodowy:adj': 6,
#              'żołnierz:subst zawodowy:adj na:prep': 29,
#              'zawodowy:adj na:prep stanowisko:subst': 11,
#              'nadterminowy:adj zasadniczy:adj służba:subst': 25,
#              'zasadniczy:adj służba:subst wojskowy:adj': 61,
#              'służba:subst wojskowy:adj i:conj': 9,
#              'służba:subst wojskowy:adj oraz:conj': 11,
#              'w:prep charakter:subst kandydat:subst': 11,
#              'charakter:subst kandydat:subst na:prep': 11,
#              'o:prep który:adj mowa:subst': 28029,
#              'który:adj mowa:subst w:prep': 27937,
#              'mowa:subst w:prep usta:subst': 12931,
#              'rodzaj:subst siła:subst zbrojny:adj': 11,
#              'w:prep porozumienie:subst z:prep': 1187,
#              'porozumienie:subst z:prep minister:subst': 985,
#              'z:prep minister:subst właściwy:adj': 670,
#              'minister:subst właściwy:adj do:prep': 7496,
#              'właściwy:adj do:prep sprawa:subst': 7567,
#              'do:prep służba:subst poza:prep': 5,
#              'służba:subst poza:prep granica:subst': 23,
#              'do:prep pełnieć:ger służba:subst': 44,
#              'pełnieć:ger służba:subst w:prep': 42,
#              'powołany:adj do:prep zawodowy:adj': 6,
#              'na:prep podstawa:subst kontrakt:subst': 26,
#              'podstawa:subst kontrakt:subst na:prep': 26,
#              'kontrakt:subst na:prep pełnieć:ger': 63,
#              'na:prep pełnieć:ger służba:subst': 64,
#              'pełnieć:ger służba:subst stała:subst': 33,
#              'lub:conj kontrakt:subst na:prep': 5,
#              'pełnieć:ger służba:subst terminowy:adj': 27,
#              'asesor:subst i:conj sędzia:subst': 15,
#              'sędzia:subst sąd:subst wojskowy:subst': 46,
#              'na:prep podstawa:subst ustawa:subst': 137,
#              'ustawa:subst z:prep dzień:subst': 6997,
#              'prawo:adv o:prep ustrój:subst': 21,
#              'o:prep ustrój:subst sąd:subst': 32,
#              'ustrój:subst sąd:subst wojskowy:subst': 11,
#              'z:prep stanowisko:subst służbowy:adj': 7,
#              'do:prep rezerwa:subst kadrowy:adj': 19,
#              'zwolnienie:subst żołnierz:subst zawodowy:adj': 16,
#              'wysoki:adj stanowisko:subst służbowy:adj': 13,
#              'zajmować:ppas stanowisko:subst służbowy:adj': 108,
#              'równorzędny:adj stanowisko:subst służbowy:adj': 5,
#              'dla:prep oficer:subst zawodowy:adj': 5,
#              'go:subst na:prep to:conj': 5,
#              'żołnierz:subst zawodowy:adj pełnić:pact': 35,
#              'zawodowy:adj pełnić:pact zawodowy:adj': 40,
#              'pełnić:pact zawodowy:adj służba:subst': 49,
#              'służba:subst wojskowy:adj na:prep': 42,
#              'wojskowy:adj na:prep stanowisko:subst': 16,
#              'sędzia:subst w:prep sąd:subst': 8,
#              'w:prep sąd:subst wojskowy:subst': 19,
#              'wojskowy:subst jednostka:subst organizacyjny:adj': 27,
#              'jednostka:subst organizacyjny:adj prokuratura:subst': 96,
#              'żołnierz:subst zawodowy:adj do:prep': 23,
#              'obowiązek:subst służbowy:adj na:prep': 6,
#              'w:prep przepis:subst ustawa:subst': 12,
#              'przepis:subst ustawa:subst z:prep': 261,
#              'o:prep powszechny:adj obowiązek:subst': 17,
#              'powszechny:adj obowiązek:subst obrona:subst': 19,
#              'obowiązek:subst obrona:subst rzeczpospolita:subst': 18,
#              'obrona:subst rzeczpospolita:subst polski:adj': 18,
#              'ministerstwo:subst obrona:subst narodowy:adj': 27,
#              'przewidzieć:ppas w:prep ustawa:subst': 39,
#              'dowódca:subst jednostka:subst wojskowy:subst': 11,
#              'w:prep stosunek:subst do:prep': 711,
#              'do:prep żołnierz:subst zawodowy:adj': 26,
#              'służba:subst wojskowy:adj w:prep': 45,
#              'stosować:fin się:qub odpowiednio:adv': 2414,
#              'mowa:subst w:prep art:ign': 11687,
#              'przez:prep właściwy:adj organ:subst': 31,
#              'określony:adj w:prep ustawa:subst': 493,
#              'na:prep zasada:subst określony:adj': 483,
#              'zasada:subst określony:adj w:prep': 638,
#              'w:prep ustawa:subst z:prep': 2423,
#              'z:prep zastrzeżenie:subst usta:subst': 828,
#              'nie:conj może:qub być:inf': 285,
#              'mianować:ger na:prep stopień:subst': 17,
#              'na:prep stopień:subst wojskowy:subst': 25,
#              'zadanie:subst służbowy:adj poza:prep': 16,
#              'stosunek:subst służbowy:adj zawodowy:adj': 24,
#              'służbowy:adj zawodowy:adj służba:subst': 24,
#              'do:prep ten:adj służba:subst': 8,
#              'rozpoczęcie:subst pełnieć:ger zawodowy:adj': 5,
#              'szef:subst sztab:subst generalny:adj': 34,
#              'sztab:subst generalny:adj wojska:subst': 40,
#              'generalny:adj wojska:subst polski:subst': 40,
#              'stopień:subst wojskowy:subst podporucznik:subst': 8,
#              'wysoki:adj szkoła:subst wojskowy:adj': 5,
#              'tytuł:subst zawodowy:adj magister:subst': 16,
#              'posiadanie:subst tytuł:subst zawodowy:adj': 5,
#              'może:qub być:inf powołany:adj': 18,
#              'w:prep korpus:subst podoficer:subst': 6,
#              'stopień:subst wojskowy:subst kapral:subst': 5,
#              'w:prep korpus:subst szeregowy:subst': 5,
#              'stopień:subst wojskowy:subst starszy:subst': 6,
#              'wojskowy:subst starszy:subst szeregowy:subst': 6,
#              'jeżeli:comp przemawiać:fin za:qub': 15,
#              'przemawiać:fin za:qub tym:conj': 15,
#              'warunek:subst określony:adj w:prep': 311,
#              'określony:adj w:prep art:ign': 2452,
#              'organ:subst uprawniony:subst do:prep': 12,
#              'bardzo:adv dobry:adj lub:conj': 6,
#              'dobry:adj lub:conj dobry:adj': 6,
#              'na:prep jak:subst zostać:praet': 6,
#              'w:prep który:adj żołnierz:subst': 46,
#              'który:adj żołnierz:subst zawodowy:adj': 19,
#              'żołnierz:subst zawodowy:adj pełnia:subst': 5,
#              'stanowisko:subst służbowy:adj dowódca:subst': 5,
#              'a:conj w:prep przypadek:subst': 233,
#              'szczegółowy:adj warunek:subst i:conj': 50,
#              'warunek:subst i:conj tryb:subst': 151,
#              'nie:conj stosować:fin się:qub': 772,
#              'i:conj sędzia:subst w:prep': 7,
#              'zachowywać:fin prawo:adv do:prep': 16,
#              'przebieg:subst zawodowy:adj służba:subst': 5,
#              'w:prep rezerwa:subst kadrowy:adj': 16,
#              'określony:adj w:prep usta:subst': 1050,
#              'prezydent:subst rzeczpospolita:subst polski:adj': 140,
#              'dyrektor:subst departament:subst ministerstwo:subst': 14,
#              'departament:subst ministerstwo:subst obrona:subst': 14,
#              'obrona:subst narodowy:adj właściwy:adj': 12,
#              'dzień:subst zwolnienie:subst z:prep': 12,
#              'zwalniać:fin się:qub z:prep': 26,
#              'zwolnienie:subst żołnierz:subst z:prep': 16,
#              'żołnierz:subst z:prep zawodowy:adj': 6,
#              'żołnierz:subst zawodowy:adj przenieść:ppas': 5,
#              'w:prep instytucja:subst cywilny:adj': 24,
#              'uposażenie:subst i:conj inny:depr': 9,
#              'i:conj inny:depr należność:subst': 11,
#              'inny:depr należność:subst pieniężny:adj': 11,
#              'określony:adj w:prep przepis:subst': 515,
#              'dla:prep żołnierz:subst zawodowy:adj': 8,
#              'zajmować:ppas przez:prep on:ppron3': 5,
#              'przez:prep on:ppron3 stanowisko:subst': 5,
#              'bezpieczeństwo:subst i:conj higiena:subst': 114,
#              'wyznaczać:ger żołnierz:subst zawodowy:adj': 7,
#              'przez:prep minister:subst obrona:subst': 15,
#              'wyznaczać:ger na:prep stanowisko:subst': 5,
#              'z:prep ten:adj stanowisko:subst': 6,
#              'stanowisko:subst służbowy:adj aplikant:subst': 5,
#              'sąd:subst wojskowy:subst oraz:conj': 19,
#              'wojskowy:subst oraz:conj aplikant:subst': 5,
#              'asesor:subst i:conj prokurator:subst': 5,
#              'skierować:ppas do:prep pełnieć:ger': 6,
#              'w:prep zależność:subst od:prep': 101,
#              'żołnierz:subst zawodowy:adj wyznaczyć:ppas': 6,
#              'granica:subst państwo:subst przysługiwać:fin': 6,
#              'miejsce:subst pełnieć:ger służba:subst': 36,
#              'stanowisko:subst służbowy:adj i:conj': 6,
#              'żołnierz:subst pełnić:pact służba:subst': 65,
#              'pełnieć:ger służba:subst poza:prep': 15,
#              'i:conj z:prep powrót:subst': 6,
#              'członek:subst rodzina:subst żołnierz:subst': 6,
#              'żołnierz:subst zawodowy:adj skierować:ppas': 6,
#              'w:prep raz:subst śmierć:subst': 29,
#              'powinien:winien w:prep szczególność:subst': 16,
#              'żołnierz:subst zawodowy:adj być:fin': 19,
#              'wyznaczyć:ppas na:prep stanowisko:subst': 9,
#              'czasowy:adj pełnieć:ger obowiązek:subst': 5,
#              'pełnieć:ger obowiązek:subst służbowy:adj': 14,
#              'zaszeregować:ppas do:prep stopień:subst': 14,
#              'do:prep stopień:subst etatowy:subst': 37,
#              'studia:subst lub:conj nauka:subst': 19,
#              'do:prep wyznaczyć:ger na:prep': 6,
#              'w:prep okresowy:adj opinia:subst': 15,
#              'okresowy:adj opinia:subst służbowy:adj': 15,
#              'na:prep zajmować:ppas stanowisko:subst': 39,
#              'dzień:subst od:prep dzień:subst': 1047,
#              'żołnierz:subst zawodowy:adj przysługiwać:fin': 12,
#              'stopień:subst wojskowy:subst odpowiadać:pact': 5,
#              'wojskowy:subst odpowiadać:pact stopień:subst': 5,
#              'odpowiadać:pact stopień:subst etatowy:subst': 6,
#              'stopień:subst etatowy:subst stanowisko:subst': 7,
#              'etatowy:subst stanowisko:subst służbowy:adj': 5,
#              'mianować:ger żołnierz:subst zawodowy:adj': 5,
#              'stosować:fin się:qub do:prep': 264,
#              'wojskowy:adj na:prep podstawa:subst': 17,
#              'ukończenie:subst kurs:subst specjalistyczny:adj': 10,
#              'kurs:subst specjalistyczny:adj dla:prep': 10,
#              'starszy:subst chorąży:subst sztabowy:adj': 8,
#              'chorąży:subst sztabowy:adj marynarka:subst': 10,
#              'się:qub do:prep żołnierz:subst': 6,
#              'wyznaczyć:ger oficer:subst zawodowy:adj': 5,
#              'oficer:subst zawodowy:adj na:prep': 5,
#              'opinia:subst służbowy:adj ogólny:adj': 9,
#              'służbowy:adj ogólny:adj ocena:subst': 9,
#              'ogólny:adj ocena:subst bardzo:adv': 6,
#              'ocena:subst bardzo:adv dobry:adj': 6,
#              'w:prep przypadek:subst uzyskać:ger': 16,
#              'przypadek:subst uzyskać:ger przez:prep': 6,
#              'oficer:subst zawodowy:adj pełnić:pact': 6,
#              'może:qub być:inf on:ppron3': 6,
#              'ogólny:adj ocena:subst dostateczny:adj': 5,
#              'wyznaczać:fin się:qub go:subst': 5,
#              'się:qub go:subst na:prep': 5,
#              'być:inf on:ppron3 zwolnić:ppas': 5,
#              'on:ppron3 zwolnić:ppas z:prep': 5,
#              'zwolnić:ppas z:prep zawodowy:adj': 36,
#              'na:prep to:conj samo:adv': 5,
#              'to:conj samo:adv lub:conj': 5,
#              'dowódca:subst rodzaj:subst siła:subst': 7,
#              'zajmujący:adj stanowisko:subst służbowy:adj': 34,
#              'z:prep zajmować:ppas stanowisko:subst': 33,
#              'w:prep odniesienie:subst do:prep': 498,
#              'odniesienie:subst do:prep stanowisko:subst': 19,
#              'do:prep stanowisko:subst służbowy:adj': 21,
#              'na:prep podstawa:subst przepis:subst': 465,
#              'wydać:ppas na:prep podstawa:subst': 584,
#              'na:prep podstawa:subst art:ign': 935,
#              'stanowisko:subst służbowy:adj do:prep': 20,
#              'służbowy:adj do:prep stopień:subst': 20,
#              'w:prep podległy:adj jednostka:subst': 12,
#              'z:prep zastrzeżenie:subst pkt:subst': 15,
#              'włącznie:adv w:prep podległy:adj': 15,
#              'podległy:adj jednostka:subst wojskowy:subst': 8,
#              'się:qub z:prep zawodowy:adj': 7,
#              'wymienić:ppas w:prep art:ign': 741,
#              'rozporządzenie:subst powinien:winien w:prep': 12,
#              'wojskowy:subst dokument:subst osobisty:adj': 12,
#              'żołnierz:subst zawodowy:adj oraz:conj': 12,
#              'w:prep czas:subst wykonywać:ger': 39,
#              'żołnierz:subst zwolnić:ppas z:prep': 25,
#              'z:prep czynny:adj służba:subst': 15,
#              'zajmować:fin stanowisko:subst służbowy:adj': 7,
#              'na:prep studia:subst lub:conj': 12,
#              'staż:subst naukowy:adj lub:conj': 5,
#              'naukowy:adj lub:conj kurs:subst': 5,
#              'zwolnienie:subst z:prep służba:subst': 80,
#              'obowiązek:subst zwrot:subst koszt:subst': 5,
#              'w:prep całość:subst lub:conj': 114,
#              'w:prep przypadek:subst gdy:adv': 447,
#              'żołnierz:subst zawodowy:adj nie:conj': 6,
#              'oraz:conj warunek:subst i:conj': 5,
#              'i:conj tryb:subst on:ppron3': 13,
#              'organ:subst właściwy:adj w:prep': 18,
#              'właściwy:adj w:prep ten:adj': 5,
#              'oraz:conj szczegółowy:adj warunek:subst': 5,
#              'wojskowy:adj w:prep przypadek:subst': 5,
#              'tryb:subst postępowanie:subst w:prep': 35,
#              'w:prep zamian:subst za:qub': 63,
#              'żołnierz:subst zawód:subst otrzymywać:fin': 5,
#              'urlop:subst wypoczynkowy:adj w:prep': 8,
#              'wypoczynkowy:adj w:prep wymiar:subst': 5,
#              'dodatkowy:adj urlop:subst wypoczynkowy:adj': 17,
#              'lato:subst czynny:adj służba:subst': 8,
#              'urlop:subst wypoczynkowy:adj i:conj': 5,
#              'wypoczynkowy:adj i:conj dodatkowy:adj': 5,
#              'i:conj dodatkowy:adj urlop:subst': 5,
#              'zwolnienie:subst od:prep zajęcia:subst': 5,
#              'od:prep zajęcia:subst służbowy:adj': 6,
#              'bliski:adj członek:subst rodzina:subst': 5,
#              'z:prep urlop:subst wypoczynkowy:adj': 6,
#              'urlop:subst wypoczynkowy:adj lub:conj': 6,
#              'pokrywa:subst się:qub z:prep': 5,
#              'z:prep część:subst budżet:subst': 7,
#              'część:subst budżet:subst państwo:subst': 7,
#              'który:adj dysponent:subst być:fin': 36,
#              'dysponent:subst być:fin minister:subst': 22,
#              'być:fin minister:subst obrona:subst': 8,
#              'dodatkowy:adj uposażenie:subst roczny:adj': 14,
#              'uposażenie:subst zasadniczy:adj i:conj': 6,
#              'zasadniczy:adj i:conj dodatek:subst': 5,
#              'dodatek:subst do:prep uposażenie:subst': 33,
#              'zasiłek:subst na:prep zagospodarować:ger': 5,
#              'nagroda:subst i:conj zapomoga:subst': 11,
#              'z:prep zwolnienie:subst z:prep': 5,
#              'śmierć:subst żołnierz:subst zawodowy:adj': 7,
#              'żołnierz:subst zawodowy:adj lub:conj': 12,
#              'członek:subst on:ppron3 rodzina:subst': 44,
#              'ekwiwalent:subst pieniężny:adj za:qub': 7,
#              'pieniężny:adj za:qub wykorzystać:ppas': 5,
#              'wykorzystać:ppas urlop:subst wypoczynkowy:adj': 5,
#              'prawo:adv do:prep uposażenie:subst': 11,
#              'z:prep dzień:subst rozpoczęcie:subst': 5,
#              'obowiązujący:adj w:prep dzień:subst': 15,
#              'uposażenie:subst zasadniczy:adj żołnierz:subst': 6,
#              'zasadniczy:adj żołnierz:subst zawodowy:adj': 6,
#              'wynikać:pact z:prep usta:subst': 5,
#              'do:prep sprawa:subst praca:subst': 142,
#              'stawek:subst uposażenie:subst zasadniczy:adj': 6,
#              'do:prep uposażenie:subst zasadniczy:adj': 8,
#              'dodatek:subst o:prep charakter:subst': 45,
#              'o:prep charakter:subst stała:subst': 53,
#              'uposażenie:subst zasadniczy:adj wraz:adv': 30,
#              'zasadniczy:adj wraz:adv z:prep': 30,
#              'wraz:adv z:prep dodatek:subst': 35,
#              'z:prep dodatek:subst o:prep': 35,
#              'służba:subst wojskowy:adj przez:prep': 7,
#              'w:prep ostatni:subst dzień:subst': 15,
#              'śmierć:subst członek:subst rodzina:subst': 5,
#              'nabycie:subst prawa:subst do:prep': 31,
#              'i:conj na:prep zasada:subst': 43,
#              'zmiana:subst maić:pact wpływ:subst': 5,
#              'maić:pact wpływ:subst na:prep': 10,
#              'służba:subst wojskowy:adj pełnić:ppas': 5,
#              'jednak:conj niż:conj do:prep': 32,
#              'który:adj żołnierz:subst zajmować:praet': 5,
#              'przez:prep wojskowy:adj komisja:subst': 6,
#              'w:prep dzień:subst śmierć:subst': 5,
#              'dzień:subst śmierć:subst żołnierz:subst': 5,
#              'który:adj w:prep dzień:subst': 10,
#              'dzień:subst rozpoczęcie:subst pełnieć:ger': 5,
#              'wypowiedzenie:subst stosunek:subst służbowy:adj': 15,
#              'z:prep moc:subst prawa:subst': 113,
#              'były:subst żołnierz:subst zawodowy:adj': 5,
#              'posiadać:ppas stopień:subst wojskowy:subst': 5,
#              'do:prep służba:subst kandydacki:adj': 13,
#              'pełnieć:ger służba:subst kandydacki:adj': 5,
#              'służba:subst kandydacki:adj z:prep': 6,
#              'pełnić:pact służba:subst kandydacki:adj': 63,
#              'wysoki:adj stopień:subst wojskowy:subst': 8,
#              'o:prep uposażenie:subst żołnierz:subst': 5,
#              'z:prep służba:subst kandydacki:adj': 7,
#              'zawodowy:adj i:conj żołnierz:subst': 22,
#              'i:conj żołnierz:subst pełnić:pact': 26,
#              'służba:subst kandydacki:adj w:prep': 16,
#              'kandydacki:adj w:prep raz:subst': 10,
#              'ogłoszenie:subst stan:subst wojenny:adj': 33,
#              'w:prep czas:subst pokój:subst': 5,
#              'żołnierz:subst zawód:subst i:conj': 5,
#              'zawodowy:adj lub:conj żołnierz:subst': 11,
#              'lub:conj żołnierz:subst pełnić:pact': 11,
#              'na:prep wysoki:adj stopień:subst': 11,
#              'wprowadzać:fin się:qub następujący:adj': 766,
#              'się:qub następujący:adj zmiana:subst': 766,
#              'uchylać:fin się:qub usta:subst': 105,
#              'uchylać:fin się:qub art:ign': 40,
#              'uchylać:fin się:qub pkt:subst': 55,
#              'okresowy:adj służba:subst wojskowy:adj': 18,
#              'wojskowy:adj renta:subst inwalidzki:adj': 7,
#              'zakład:subst ubezpieczenie:subst społeczny:adj': 211,
#              'nie:conj długo:adv jednak:conj': 39,
#              'długo:adv jednak:conj niż:conj': 39,
#              'młody:adj chorąży:subst sztabowy:adj': 6,
#              'ustawa:subst zostać:praet ogłosić:ppas': 654,
#              'zostać:praet ogłosić:ppas w:prep': 667,
#              'śródlądowy:adj droga:subst wodny:adj': 42,
#              'organ:subst administracja:subst żegluga:subst': 10,
#              'administracja:subst żegluga:subst śródlądowy:adj': 10,
#              'żegluga:subst śródlądowy:adj i:conj': 5,
#              'statek:subst żegluga:subst śródlądowy:adj': 12,
#              'na:prep śródlądowy:adj droga:subst': 10,
#              'o:prep napęd:subst mechaniczny:adj': 12,
#              'bez:prep napęd:subst mechaniczny:adj': 9,
#              'uprawianie:subst sport:subst lub:conj': 10,
#              'sport:subst lub:conj rekreacja:subst': 10,
#              'do:prep sprawa:subst transport:subst': 325,
#              'dyrektor:subst urząd:subst żegluga:subst': 37,
#              'urząd:subst żegluga:subst śródlądowy:adj': 48,
#              'sprawa:subst transport:subst określić:fin': 34,
#              'maić:pcon na:prep wzgląd:subst': 239,
#              'w:prep żegluga:subst śródlądowy:adj': 6,
#              'w:prep droga:subst decyzja:subst': 548,
#              'droga:subst decyzja:subst administracyjny:adj': 100,
#              'świadectwo:subst zdolność:subst żeglugowy:adj': 31,
#              'administracja:subst droga:subst wodny:adj': 6,
#              'żegluga:subst śródlądowy:adj właściwy:adj': 5,
#              'używać:ppas wyłącznie:adv do:prep': 6,
#              'wyłącznie:adv do:prep uprawianie:subst': 7,
#              'do:prep uprawianie:subst sport:subst': 9,
#              'polski:adj instytucja:subst klasyfikacyjny:adj': 7,
#              'obowiązek:subst korzystać:ger z:prep': 14,
#              'pobierać:fin się:qub opłata:subst': 38,
#              'się:qub opłata:subst w:prep': 21,
#              'opłata:subst w:prep wysokość:subst': 23,
#              'w:prep wysokość:subst określony:adj': 34,
#              'wysokość:subst określony:adj w:prep': 28,
#              'określony:adj w:prep załącznik:subst': 94,
#              'w:prep załącznik:subst do:prep': 23,
#              'załącznik:subst do:prep ustawa:subst': 41,
#              'statek:subst używać:ppas do:prep': 6,
#              'wymóg:subst zdolność:subst zawodowy:adj': 7,
#              'zaświadczenie:subst o:prep spełnienie:subst': 5,
#              'o:prep spełnienie:subst wymóg:subst': 5,
#              'spełnienie:subst wymóg:subst zdolność:subst': 7,
#              'obowiązujący:adj w:prep wspólnota:subst': 5,
#              'w:prep wspólnota:subst europejski:adj': 5,
#              'wpis:subst do:prep rejestr:subst': 324,
#              'napęd:subst mechaniczny:adj o:prep': 14,
#              'mechaniczny:adj o:prep iloczyn:subst': 7,
#              'o:prep iloczyn:subst długość:subst': 6,
#              'iloczyn:subst długość:subst i:conj': 5,
#              'mechaniczny:adj o:prep moc:subst': 7,
#              'statek:subst do:prep rejestr:subst': 6,
#              'przeznaczyć:ppas do:prep przewóz:subst': 13,
#              'do:prep przewóz:subst ładunek:subst': 12,
#              'on:ppron3 stała:subst urządzenie:subst': 11,
#              'wydawać:fin dyrektor:subst urząd:subst': 5,
#              'dopuścić:ger statek:subst do:prep': 5,
#              'na:prep statek:subst żegluga:subst': 5,
#              'członek:subst załoga:subst statek:subst': 6,
#              'żeglarski:adj książeczka:subst praca:subst': 9,
#              'przewóz:subst materiał:subst niebezpieczny:adj': 23,
#              'świadectwo:subst ekspert:subst adn:subst': 7,
#              'na:prep droga:subst wodny:adj': 5,
#              'korzystać:ger z:prep pilotaż:subst': 12,
#              'z:prep obowiązek:subst korzystać:ger': 10,
#              'świadectwo:subst zwolnienie:subst z:prep': 9,
#              'zwolnienie:subst z:prep obowiązek:subst': 23,
#              'podlegać:fin kar:subst grzywna:subst': 259,
#              'do:prep sprawa:subst gospodarka:subst': 915,
#              'sprawa:subst gospodarka:subst wodny:adj': 61,
#              'odprowadzać:ger i:conj oczyszczać:ger': 5,
#              'i:conj oczyszczać:ger ściek:subst': 5,
#              'wchodzić:fin w:prep życie:subst': 136,
#              'w:prep życie:subst z:prep': 52,
#              'życie:subst z:prep dzień:subst': 52,
#              'narodowy:adj bank:subst polski:subst': 187,
#              'który:adj wykonywać:ger następować:fin': 6,
#              'wykonywać:ger następować:fin poprzez:prep': 6,
#              'następować:fin poprzez:prep dokonywać:ger': 6,
#              'poprzez:prep dokonywać:ger rozliczenie:subst': 6,
#              'dokonywać:ger rozliczenie:subst pieniężny:adj': 6,
#              'nierezydent:subst z:prep kraj:subst': 7,
#              'z:prep kraj:subst trzeci:subst': 19,
#              'wartość:subst dewizowy:adj lub:conj': 29,
#              'dewizowy:adj lub:conj krajowy:adj': 29,
#              'lub:conj krajowy:adj środek:subst': 32,
#              'krajowy:adj środek:subst płatniczy:adj': 47,
#              'rezydent:subst i:conj nierezydent:subst': 14,
#              'wykonywać:ger działalność:subst kantorowa:subst': 6,
#              'organ:subst celny:adj lub:conj': 5,
#              'organ:subst straż:subst graniczny:adj': 35,
#              'przywóz:subst do:prep kraj:subst': 6,
#              'wywóz:subst za:qub granica:subst': 27,
#              'za:qub granica:subst wartość:subst': 5,
#              'granica:subst wartość:subst dewizowy:adj': 5,
#              'kar:subst grzywna:subst do:prep': 136,
#              'kto:subst wbrew:adv obowiązek:subst': 23,
#              'przywóz:subst na:prep polski:subst': 66,
#              'na:prep polski:subst obszar:subst': 303,
#              'polski:subst obszar:subst celny:adj': 414,
#              'towar:subst tekstylna:subst i:conj': 16,
#              'tekstylna:subst i:conj odzieżowy:adj': 18,
#              'dzień:subst od:prep data:subst': 74,
#              'władza:subst kraj:subst eksport:subst': 12,
#              'towar:subst objąć:ppas postępowanie:subst': 77,
#              'objąć:ppas postępowanie:subst ochronny:adj': 37,
#              'obszar:subst celny:adj towar:subst': 48,
#              'towar:subst pochodzić:pact z:prep': 27,
#              'zastosowanie:subst środek:subst ochronny:adj': 5,
#              'wszcząć:ger postępowanie:subst ochronny:adj': 39,
#              'o:prep wszcząć:ger postępowanie:subst': 50,
#              'w:prep tok:subst postępowanie:subst': 71,
#              'tok:subst postępowanie:subst ochronny:adj': 15,
#              'zespół:subst kuratorski:adj służba:subst': 9,
#              'kuratorski:adj służba:subst sądowy:adj': 19,
#              'prezes:subst sąd:subst okręgowy:adj': 144,
#              'na:prep wniosek:subst kurator:subst': 8,
#              'wniosek:subst kurator:subst okręgowy:adj': 7,
#              'się:qub odpowiednio:adv przepis:subst': 332,
#              'kurator:subst zawodowy:adj przysługiwać:fin': 7,
#              'w:prep uzasadniony:adj wypadek:subst': 5,
#              'przez:prep prezes:subst sąd:subst': 15,
#              'prezes:subst sąd:subst rejonowy:adj': 31,
#              'po:prep zasięgnąć:ger opinia:subst': 437,
#              'kierownik:subst zespół:subst kuratorski:adj': 7,
#              'krajowy:adj rad:subst kurator:subst': 9,
#              'kurator:subst okręgowy:adj i:conj': 9,
#              'miesiąc:subst od:prep dzień:subst': 639,
#              'z:prep kurator:subst zawodowy:adj': 8,
#              'stosunek:subst praca:subst z:prep': 68,
#              'praca:subst z:prep kurator:subst': 7,
#              'do:prep minister:subst sprawiedliwość:subst': 5,
#              'zastępca:subst kurator:subst okręgowy:adj': 9,
#              'okręgowy:adj zgromadzenie:subst kurator:subst': 22,
#              'okręgowy:adj i:conj on:ppron3': 5,
#              'i:conj on:ppron3 zastępca:subst': 74,
#              'krajowy:adj rada:subst kurator:subst': 6,
#              'członek:subst sąd:subst dyscyplinarny:adj': 8,
#              'sąd:subst dyscyplinarny:adj pierwsza:subst': 10,
#              'dyscyplinarny:adj pierwsza:subst instancja:subst': 10,
#              'sąd:subst dyscyplinarny:adj druga:subst': 7,
#              'dyscyplinarny:adj druga:subst instancja:subst': 7,
#              'członek:subst komisja:subst egzaminacyjny:adj': 32,
#              'orzeczenie:subst sąd:subst dyscyplinarny:adj': 11,
#              'wywiad:subst środowiskowy:adj w:prep': 5,
#              'dzień:subst wejście:subst w:prep': 1445,
#              'wejście:subst w:prep życie:subst': 1722,
#              'w:prep życie:subst ustawa:subst': 734,
#              'dochód:subst budżet:subst państwo:subst': 66,
#              'do:prep sprawa:subst finanse:subst': 802,
#              'w:prep załącznik:subst nr:subst': 237,
#              'upoważniać:fin się:qub minister:subst': 57,
#              'się:qub minister:subst właściwy:adj': 41,
#              'sprawa:subst finanse:subst do:prep': 34,
#              'skarbowy:adj papier:subst wartościowy:adj': 72,
#              'określać:fin załącznik:subst nr:subst': 23,
#              'przeznaczyć:ppas do:prep sprzedaż:subst': 109,
#              'nie:conj może:qub przekroczyć:inf': 77,
#              'państwowy:adj jednostka:subst budżetowy:adj': 49,
#              'dotacja:subst na:prep dofinansować:ger': 5,
#              'do:prep sprawa:subst budżet:subst': 14,
#              'środek:subst na:prep wynagrodzenie:subst': 13,
#              'osoba:subst zajmujący:adj kierowniczy:adj': 23,
#              'zajmujący:adj kierowniczy:adj stanowisko:subst': 23,
#              'kierowniczy:adj stanowisko:subst państwowy:adj': 29,
#              'żołnierz:subst i:conj funkcjonariusz:subst': 6,
#              'jednostka:subst gospodarka:subst pozabudżetowy:adj': 17,
#              'limit:subst wynagrodzenie:subst dla:prep': 19,
#              'zasada:subst i:conj tryb:subst': 190,
#              'wynagrodzenie:subst w:prep państwowy:adj': 15,
#              'w:prep państwowy:adj sfera:subst': 20,
#              'państwowy:adj sfera:subst budżetowy:adj': 47,
#              'osoba:subst objąć:ppas mnożnikowy:adj': 5,
#              'objąć:ppas mnożnikowy:adj system:subst': 8,
#              'mnożnikowy:adj system:subst wynagrodzenie:subst': 8,
#              'o:prep finanse:subst publiczny:adj': 61,
#              'średnioroczny:adj wskaźnik:subst wzrost:subst': 11,
#              'wskaźnik:subst wzrost:subst wynagrodzenie:subst': 11,
#              'wielokrotność:subst kwota:subst bazowy:adj': 20,
#              'wzrost:subst wynagrodzenie:subst w:prep': 5,
#              'stan:subst wielokrotność:subst kwota:subst': 7,
#              'który:adj wysokość:subst ustalić:ppas': 15,
#              'wysokość:subst ustalić:ppas według:prep': 15,
#              'ustalić:ppas według:prep odrębny:adj': 15,
#              'według:prep odrębny:adj zasada:subst': 15,
#              'odrębny:adj zasada:subst określać:fin': 15,
#              'zasada:subst określać:fin ustawa:subst': 15,
#              'określać:fin ustawa:subst budżetowy:adj': 15,
#              'określać:fin rada:subst minister:subst': 5,
#              'rada:subst minister:subst w:prep': 5,
#              'minister:subst w:prep droga:subst': 5,
#              'przeciętna:subst uposażenie:subst funkcjonariusz:subst': 5,
#              'prawny:adj kontrola:subst metrologiczny:adj': 20,
#              'organ:subst administracja:subst miara:subst': 24,
#              'dodawać:fin się:qub usta:subst': 2139,
#              'okręgowy:adj urząd:subst miara:subst': 25,
#              'główny:adj urząd:subst miara:subst': 22,
#              'w:prep tym:conj zakres:subst': 102,
#              'państwowy:adj wzorzec:subst jednostka:subst': 18,
#              'wzorzec:subst jednostka:subst miara:subst': 31,
#              'dyrektor:subst okręgowy:adj urząd:subst': 5,
#              'naczelnik:subst obwodowy:adj urząd:subst': 7,
#              'obwodowy:adj urząd:subst miara:subst': 13,
#              'od:prep dzień:subst wejście:subst': 254,
#              'ustawa:subst zmieniać:ppas w:prep': 496,
#              'zmieniać:ppas w:prep art:ign': 496,
#              'towar:subst lub:conj usługa:subst': 26,
#              'audycja:subst lub:conj inny:subst': 8,
#              'lub:conj inny:subst przekaz:subst': 14,
#              'reklama:subst lub:conj inny:subst': 6,
#              'nadawca:subst program:subst telewizyjny:adj': 5,
#              'przeznaczać:fin co:comp mało:adv': 5,
#              'kwartalne:subst czas:subst nadawanie:subst': 12,
#              'czas:subst nadawanie:subst program:subst': 14,
#              'w:prep język:subst polski:subst': 24,
#              'z:prep uwzględnienie:subst charakter:subst': 5,
#              'krajowy:adj rada:subst może:qub': 5,
#              'w:prep program:subst radiowy:adj': 6,
#              'dodawać:fin się:qub art:ign': 977,
#              'krajowy:adj rada:subst określić:fin': 7,
#              'reklama:subst i:conj telesprzedaż:subst': 5,
#              'w:prep cel:subst nadanie:subst': 5,
#              'cel:subst nadanie:subst reklama:subst': 5,
#              'nadanie:subst reklama:subst lub:conj': 5,
#              'reklama:subst lub:conj telesprzedaż:subst': 6,
#              'audycja:subst lub:conj inny:depr': 7,
#              'lub:conj inny:depr przekaz:subst': 8,
#              'świadczenie:subst opieka:subst zdrowotny:adj': 186,
#              'uprawniony:subst żołnierz:subst lub:conj': 7,
#              'żołnierz:subst lub:conj pracownik:subst': 8,
#              'podczas:prep wykonywać:ger zadanie:subst': 14,
#              'choroba:subst nabyć:ppas podczas:prep': 5,
#              'nabyć:ppas podczas:prep wykonywać:ger': 5,
#              'wykonywać:ger zadanie:subst poza:prep': 15,
#              'zadanie:subst poza:prep granica:subst': 11,
#              'na:prep rynek:subst krajowy:adj': 23,
#              'produkt:subst w:prep opakowanie:subst': 30,
#              'produkt:subst wymienić:ppas w:prep': 20,
#              'wymienić:ppas w:prep załącznik:subst': 46,
#              'opakowanie:subst wymienić:ppas w:prep': 6,
#              'odpad:subst opakowaniowy:adj i:conj': 14,
#              'przepis:subst o:prep odpad:subst': 12,
#              'rozum:subst się:qub przez:prep': 667,
#              'się:qub przez:prep to:conj': 667,
#              'w:prep rozumienie:subst przepis:subst': 255,
#              'rozumienie:subst przepis:subst o:prep': 91,
#              'punkt:subst system:subst zbiórka:subst': 5,
#              'recykling:subst odpad:subst opakowaniowy:adj': 12,
#              'opakowaniowy:adj i:conj poużytkowy:adj': 13,
#              'poziom:subst odzysk:subst i:conj': 9,
#              'odzysk:subst i:conj recykling:subst': 19,
#              'i:conj recykling:subst odpad:subst': 13,
#              'masa:subst lub:conj ilość:subst': 10,
#              'ilość:subst odpad:subst opakowaniowy:adj': 5,
#              'wprowadzić:ppas na:prep rynek:subst': 5,
#              'opakowanie:subst lub:conj produkt:subst': 7,
#              'osiągnąć:ppas poziom:subst odzysk:subst': 5,
#              'do:prep sprawa:subst środowisko:subst': 589,
#              'być:fin obowiązany:subst do:prep': 220,
#              'odpowiednio:adv masa:subst lub:conj': 6,
#              'z:prep podział:subst na:prep': 19,
#              'podział:subst na:prep poszczególny:adj': 9,
#              'na:prep poszczególny:adj on:ppron3': 6,
#              'poszczególny:adj on:ppron3 rodzaj:subst': 6,
#              'w:prep termin:subst do:prep': 332,
#              'termin:subst do:prep dzień:subst': 192,
#              'wymienić:ppas w:prep poz:ign': 29,
#              'dla:prep produkt:subst wymienić:ppas': 8,
#              'złoty:brev za:qub sztuka:subst': 5,
#              'odpad:subst poużytkowy:adj z:prep': 6,
#              'rok:subst kalendarzowy:adj następujący:adj': 6,
#              'kalendarzowy:adj następujący:adj po:prep': 6,
#              'następujący:adj po:prep rok:subst': 12,
#              'na:prep odrębny:adj rachunek:subst': 8,
#              'odrębny:adj rachunek:subst bankowy:adj': 9,
#              'z:prep tytuł:subst opłata:subst': 16,
#              'tytuł:subst opłata:subst produktowy:adj': 9,
#              'z:prep opłata:subst produktowy:adj': 7,
#              'wpływ:subst z:prep tytuł:subst': 14,
#              'rachunek:subst bankowy:adj narodowy:adj': 8,
#              'bankowy:adj narodowy:adj fundusz:subst': 8,
#              'opłata:subst produktowy:adj od:prep': 6,
#              'produktowy:adj od:prep sprzedaż:subst': 6,
#              'od:prep sprzedaż:subst produkt:subst': 6,
#              'być:fin gromadzić:ppas na:prep': 6,
#              'gromadzić:ppas na:prep odrębny:adj': 6,
#              'narodowy:adj fundusz:subst przeznaczać:fin': 6,
#              'fundusz:subst przeznaczać:fin na:prep': 6,
#              'przeznaczać:fin na:prep finansować:ger': 6,
#              'do:prep ustawa:subst być:fin': 5,
#              'ustawa:subst być:fin gromadzić:ppas': 5,
#              'substancja:subst zubożać:pact warstwa:subst': 21,
#              'zubożać:pact warstwa:subst ozonowy:adj': 21,
#              'bez:prep wzgląd:subst na:prep': 72,
#              'zawierać:pact substancja:subst zubożać:pact': 6,
#              'cfc:subst i:conj hcfc:ign': 6,
#              'o:prep zrekompensować:ger okresowy:adj': 7,
#              'zrekompensować:ger okresowy:adj podwyższać:ger': 7,
#              'okresowy:adj podwyższać:ger płaca:subst': 7,
#              'podwyższać:ger płaca:subst w:prep': 7,
#              'płaca:subst w:prep sfera:subst': 7,
#              'w:prep sfera:subst budżetowy:adj': 7,
#              'sfera:subst budżetowy:adj oraz:conj': 12,
#              'budżetowy:adj oraz:conj utrata:subst': 7,
#              'oraz:conj utrata:subst niektóry:subst': 7,
#              'utrata:subst niektóry:subst wzrost:subst': 7,
#              'niektóry:subst wzrost:subst lub:conj': 7,
#              'wzrost:subst lub:conj dodatek:subst': 13,
#              'lub:conj dodatek:subst do:prep': 7,
#              'dodatek:subst do:prep emerytura:subst': 14,
#              'do:prep emerytura:subst i:conj': 16,
#              'emerytura:subst i:conj renta:subst': 237,
#              'zastępować:fin się:qub wyraz:subst': 3206,
#              'nominalny:adj wartość:subst rekompensata:subst': 8,
#              'do:prep sprawa:subst administracja:subst': 201,
#              'sprawa:subst administracja:subst publiczny:adj': 199,
#              'wjazd:subst na:prep terytorium:subst': 33,
#              'na:prep terytorium:subst rzeczpospolita:subst': 731,
#              'terytorium:subst rzeczpospolita:subst polski:adj': 922,
#              'z:prep terytorium:subst rzeczpospolita:subst': 20,
#              'zezwolenie:subst na:prep zamieszkanie:subst': 84,
#              'na:prep zamieszkanie:subst na:prep': 84,
#              'zamieszkanie:subst na:prep czas:pred': 84,
#              'na:prep czas:pred oznaczony:adj': 115,
#              'kart:subst stały:adj pobyt:subst': 12,
#              'tymczasowy:adj dokument:subst podróż:subst': 9,
#              'bezpieczny:adj kraj:subst trzeci:subst': 5,
#              'postępowanie:subst o:prep nadanie:subst': 39,
#              'o:prep nadanie:subst status:subst': 87,
#              'nadanie:subst status:subst uchodźca:subst': 98,
#              'rzeczpospolita:subst polski:adj w:prep': 29,
#              'w:prep rzeczpospolita:subst polski:adj': 219,
#              'pobytowy:adj z:prep prawo:subst': 5,
#              'z:prep prawo:subst do:prep': 29,
#              'prawo:subst do:prep praca:subst': 5,
#              'pobyt:subst na:prep terytorium:subst': 26,
#              'inny:adj praca:subst zarobkowy:adj': 106,
#              'wydawać:fin się:qub na:prep': 18,
#              'nie:conj długi:adj niż:conj': 148,
#              'przebywać:pact na:prep terytorium:subst': 12,
#              'zatrudnienie:subst lub:conj wykonywać:ger': 13,
#              'lub:conj wykonywać:ger inny:adj': 13,
#              'wykonywać:ger inny:adj praca:subst': 20,
#              'do:prep rzeczpospolita:subst polski:adj': 15,
#              'decyzja:subst o:prep wydalić:ger': 35,
#              'istnieć:fin uzasadniony:adj podejrzenie:subst': 14,
#              'okoliczność:subst określony:adj w:prep': 10,
#              'cudzoziemiec:subst posiadający:adj zezwolenie:subst': 5,
#              'posiadający:adj zezwolenie:subst na:prep': 5,
#              'zezwolenie:subst na:prep osiedlić:ger': 55,
#              'na:prep osiedlić:ger się:qub': 57,
#              'do:prep ewidencja:subst zaproszenie:subst': 5,
#              'którykolwiek:adj z:prep okoliczność:subst': 16,
#              'z:prep okoliczność:subst wymienić:ppas': 7,
#              'okoliczność:subst wymienić:ppas w:prep': 17,
#              'się:qub o:prep nadanie:subst': 27,
#              'wniosek:subst o:prep nadanie:subst': 23,
#              'wszcząć:ger postępowanie:subst o:prep': 17,
#              'postanowienie:subst o:prep wszcząć:ger': 25,
#              'tymczasowy:adj zaświadczenie:subst tożsamość:subst': 13,
#              'umieścić:ger cudzoziemiec:subst w:prep': 5,
#              'o:prep nadanie:subst lub:conj': 13,
#              'w:prep konwencja:subst genewski:adj': 16,
#              'dokument:subst podróż:subst przewidzieć:ppas': 13,
#              'podróż:subst przewidzieć:ppas w:prep': 13,
#              'przewidzieć:ppas w:prep konwencja:subst': 14,
#              'w:prep strzec:ppas ośrodek:subst': 24,
#              'w:prep decyzja:subst o:prep': 5,
#              'do:prep sprawa:subst uchodźca:subst': 10,
#              'strzec:ppas ośrodek:subst albo:conj': 8,
#              'areszt:subst w:prep cel:subst': 33,
#              'w:prep cel:subst wydalić:ger': 33,
#              'przedstawicielstwo:subst dyplomatyczny:adj lub:conj': 7,
#              'dyplomatyczny:adj lub:conj urząd:subst': 7,
#              'lub:conj urząd:subst konsularny:adj': 7,
#              'się:qub według:prep przepis:subst': 5,
#              'kierownik:subst polski:subst przedstawicielstwo:subst': 6,
#              'polski:subst przedstawicielstwo:subst dyplomatyczny:adj': 12,
#              'rejestr:subst złożone:subst wniosek:subst': 10,
#              'i:conj wydać:ppas w:prep': 11,
#              'wydać:ppas w:prep ten:adj': 11,
#              'ten:adj sprawa:subst decyzja:subst': 11,
#              'wniosek:subst o:prep udzielić:ger': 82,
#              'minister:subst sprawa:subst wewnętrzny:subst': 360,
#              'sprawa:subst wewnętrzny:subst i:conj': 279,
#              'wewnętrzny:subst i:conj administracja:subst': 252,
#              'i:conj administracja:subst w:prep': 12,
#              'w:prep sprawa:subst o:prep': 400,
#              'sprawa:subst o:prep nadanie:subst': 12,
#              'prezes:subst rad:subst minister:subst': 696,
#              'minister:subst sprawa:subst zagraniczny:adj': 24,
#              'postępowanie:subst w:prep sprawa:subst': 388,
#              'przedstawicielstwo:subst dyplomatyczny:adj i:conj': 5,
#              'dyplomatyczny:adj i:conj urząd:subst': 5,
#              'i:conj urząd:subst konsularny:adj': 5,
#              'wojewoda:subst właściwy:adj z:prep': 30,
#              'właściwy:adj z:prep wzgląd:subst': 209,
#              'wzgląd:subst na:prep miejsce:subst': 157,
#              'na:prep miejsce:subst pobyt:subst': 16,
#              'miejsce:subst pobyt:subst cudzoziemiec:subst': 15,
#              'komendant:subst graniczny:adj placówka:subst': 35,
#              'graniczny:adj placówka:subst kontrolny:adj': 53,
#              'placówka:subst kontrolny:adj straż:subst': 32,
#              'kontrolny:adj straż:subst graniczny:adj': 32,
#              'i:conj administracja:subst określić:fin': 26,
#              'z:prep minister:subst sprawa:subst': 31,
#              'administracja:subst w:prep porozumienie:subst': 5,
#              'polski:adj organizacja:subst turystyczny:adj': 78,
#              'w:prep dziedzina:subst turystyka:subst': 6,
#              'polska:subst organizacja:subst turystyczny:adj': 17,
#              'organizacja:subst turystyczny:adj być:fin': 5,
#              'kultura:subst fizyczny:adj i:conj': 136,
#              'fizyczny:adj i:conj turystyka:subst': 53,
#              'organizacja:subst turystyczny:adj może:qub': 6,
#              'rada:subst polski:adj organizacja:subst': 5,
#              'prezes:subst polski:adj organizacja:subst': 15,
#              'rad:subst polski:adj organizacja:subst': 14,
#              'roczny:adj plan:subst finansowy:adj': 16,
#              'działalność:subst polski:adj organizacja:subst': 5,
#              'roczny:adj sprawozdanie:subst finansowy:adj': 75,
#              'sprawozdanie:subst finansowy:adj polski:adj': 5,
#              'finansowy:adj polski:adj organizacja:subst': 9,
#              'organizacja:subst turystyczny:adj w:prep': 5,
#              'działalność:subst gospodarczy:adj w:prep': 143,
#              'zakład:subst wymienić:ppas w:prep': 5,
#              'rejonowy:adj urząd:subst praca:subst': 139,
#              'przez:prep okres:subst co:comp': 24,
#              'okres:subst co:comp mało:adv': 25,
#              'środek:subst fundusz:subst praca:subst': 29,
#              'nie:conj późno:adv niż:conj': 265,
#              'składka:subst na:prep ubezpieczenie:subst': 544,
#              'ośrodek:subst pomoc:subst społeczny:adj': 29,
#              'pozbawić:ppas całkowicie:adv lub:conj': 5,
#              'całkowicie:adv lub:conj częściowo:adv': 5,
#              'opieka:subst i:conj wychowanie:subst': 17,
#              'rodzinny:adj opieka:subst zastępczy:adj': 9,
#              'maić:pact na:prep cel:subst': 82,
#              'standard:subst wychowanie:subst i:conj': 6,
#              'wychowanie:subst i:conj opieka:subst': 6,
#              'w:prep placówka:subst opiekuńczo:adv': 13,
#              'do:prep sprawa:subst zabezpieczenie:subst': 165,
#              'sprawa:subst zabezpieczenie:subst społeczny:adj': 162,
#              'dom:subst pomoc:subst społeczny:adj': 178,
#              'kierownik:subst powiatowy:adj centrum:subst': 16,
#              'powiatowy:adj centrum:subst pomoc:subst': 28,
#              'centrum:subst pomoc:subst rodzina:subst': 28,
#              'dodawać:fin się:qub wyraz:subst': 1094,
#              'w:prep rodzina:subst zastępczy:adj': 26,
#              'dziecko:subst w:prep rodzina:subst': 5,
#              'na:prep miejsce:subst zamieszkanie:subst': 32,
#              'pełnieć:ger funkcja:subst rodzina:subst': 8,
#              'funkcja:subst rodzina:subst zastępczy:adj': 9,
#              'pomoc:subst rodzina:subst lub:conj': 5,
#              'pomoc:subst pieniężny:adj na:prep': 18,
#              'pieniężny:adj na:prep częściowy:adj': 6,
#              'na:prep częściowy:adj pokrycie:subst': 7,
#              'częściowy:adj pokrycie:subst koszt:subst': 5,
#              'pokrycie:subst koszt:subst utrzymanie:subst': 5,
#              'wysokość:subst pomoc:subst pieniężny:adj': 5,
#              'zabezpieczenie:subst społeczny:adj w:prep': 5,
#              'społeczny:adj w:prep porozumienie:subst': 11,
#              'i:conj wychowanie:subst oraz:conj': 5,
#              'powiat:subst właściwy:adj z:prep': 6,
#              'opłata:subst za:qub pobyt:subst': 25,
#              'za:qub pobyt:subst w:prep': 21,
#              'pobyt:subst w:prep dom:subst': 15,
#              'w:prep dom:subst pomoc:subst': 45,
#              'jednostka:subst organizacyjny:adj pomoc:subst': 12,
#              'organizacyjny:adj pomoc:subst społeczny:adj': 12,
#              'i:conj przepis:subst ogólny:adj': 12,
#              'przepis:subst ogólny:adj art:ign': 22,
#              'towar:subst na:prep polski:subst': 42,
#              'obszar:subst celny:adj oraz:conj': 6,
#              'z:prep polski:subst obszar:subst': 27,
#              'prawa:subst i:conj obowiązek:subst': 49,
#              'obszar:subst celny:adj lub:conj': 34,
#              'celny:adj lub:conj on:ppron3': 5,
#              'przewidzieć:ppas w:prep przepis:subst': 42,
#              'w:prep przepis:subst prawa:subst': 30,
#              'przepis:subst prawa:subst celny:adj': 74,
#              'lub:conj z:prep on:ppron3': 5,
#              'organ:subst celny:adj w:prep': 5,
#              'przez:prep organ:subst celny:adj': 65,
#              'celny:adj w:prep cel:subst': 6,
#              'należność:subst celny:adj przywozowy:adj': 132,
#              'dług:subst celny:adj w:prep': 16,
#              'celny:adj w:prep przywóz:subst': 8,
#              'należność:subst celny:adj wywozowy:adj': 13,
#              'się:qub do:prep towar:subst': 8,
#              'osoba:subst zobowiązana:subst do:prep': 14,
#              'kwota:subst wynikać:pact z:prep': 37,
#              'wynikać:pact z:prep dług:subst': 25,
#              'z:prep dług:subst celny:adj': 25,
#              'celny:adj przywozowy:adj i:conj': 5,
#              'rewizja:subst celny:adj towar:subst': 5,
#              'obniżyć:ppas stawek:subst celny:adj': 6,
#              'miejsce:subst wyznaczyć:ppas lub:conj': 7,
#              'wyznaczyć:ppas lub:conj uznany:adj': 7,
#              'lub:conj uznany:adj przez:prep': 7,
#              'uznany:adj przez:prep organ:subst': 6,
#              'który:adj móc:fin być:inf': 54,
#              'poza:prep polski:subst obszar:subst': 41,
#              'towar:subst może:qub być:inf': 5,
#              'wartość:subst celny:adj towar:subst': 37,
#              'środek:subst polityka:subst handlowy:adj': 14,
#              'zgodnie:adv z:prep warunek:subst': 7,
#              'z:prep warunek:subst określony:adj': 17,
#              'obszar:subst celny:adj i:conj': 9,
#              'dopuścić:ppas do:prep obrót:subst': 144,
#              'obszar:subst celny:adj z:prep': 5,
#              'towar:subst określony:adj w:prep': 9,
#              'niż:conj określony:adj w:prep': 97,
#              'określony:adj w:prep pkt:subst': 53,
#              'do:prep korzystać:ger z:prep': 41,
#              'na:prep rzecz:subst który:adj': 6,
#              'z:prep przepis:subst prawa:subst': 38,
#              'objęcie:subst towar:subst procedura:subst': 15,
#              'towar:subst procedura:subst celny:adj': 17,
#              'do:prep wolne:subst obszar:subst': 13,
#              'wolne:subst obszar:subst celny:adj': 86,
#              'na:prep rzecz:subst skarb:subst': 21,
#              'rzecz:subst skarb:subst państwo:subst': 21,
#              'dopuścić:ger do:prep obrót:subst': 235,
#              'przetwarzanie:subst pod:prep kontrola:subst': 18,
#              'pod:prep kontrola:subst celny:adj': 20,
#              'przywóz:subst lub:conj wywóz:subst': 19,
#              'prezes:subst główny:adj urząd:subst': 178,
#              'główny:adj urząd:subst cło:subst': 109,
#              'wiążący:adj informacja:subst taryfowy:adj': 21,
#              'kod:subst taryfa:subst celny:adj': 16,
#              'celny:adj przywozowy:adj lub:conj': 16,
#              'przywozowy:adj lub:conj celny:adj': 6,
#              'lub:conj celny:adj wywozowy:adj': 6,
#              'urząd:subst cło:subst określić:fin': 21,
#              'w:prep droga:subst zarządzenie:subst': 186,
#              'należeć:fin do:prep on:ppron3': 6,
#              'do:prep on:ppron3 dołączyć:inf': 6,
#              'organ:subst celny:adj może:qub': 120,
#              'znajdować:pact się:qub na:prep': 50,
#              'w:prep każdy:adj czas:subst': 38,
#              'obszar:subst celny:adj w:prep': 14,
#              'wprowadzić:ppas na:prep polski:subst': 14,
#              'celny:adj zgodnie:adv z:prep': 6,
#              'zgodnie:adv z:prep przepis:subst': 259,
#              'minister:subst finanse:subst określić:fin': 27,
#              'urząd:subst cło:subst może:qub': 9,
#              'cło:subst może:qub określić:inf': 5,
#              'być:fin zobowiązana:subst do:prep': 8,
#              'w:prep wypadek:subst gdy:adv': 23,
#              'do:prep działalność:subst gospodarczy:adj': 11,
#              'żądanie:subst organ:subst celny:adj': 6,
#              'zgłoszenie:subst celny:adj o:prep': 5,
#              'o:prep dopuścić:ger do:prep': 75,
#              'towar:subst dopuścić:ppas do:prep': 8,
#              'do:prep obrót:subst w:prep': 49,
#              'pod:prep dozór:subst celny:adj': 5,
#              'wzgląd:subst na:prep przeznaczenie:subst': 10,
#              'celny:adj przywozowy:adj z:prep': 11,
#              'przywozowy:adj z:prep wzgląd:subst': 10,
#              'z:prep wolne:subst obszar:subst': 8,
#              'termin:subst określony:adj w:prep': 122,
#              'sprawowanie:subst dozór:subst celny:adj': 6,
#              'na:prep wniosek:subst zgłaszać:pact': 10,
#              'wzgląd:subst na:prep on:ppron3': 32,
#              'na:prep on:ppron3 przeznaczenie:subst': 30,
#              'do:prep objęcia:subst towar:subst': 11,
#              'objęcia:subst towar:subst procedura:subst': 13,
#              'z:prep zastosowanie:subst obniżyć:ppas': 5,
#              'produkt:subst wydobyć:ppas z:prep': 5,
#              'mowa:subst w:prep pkt:subst': 302,
#              'w:prep rozumienie:subst art:ign': 142,
#              'celny:adj może:qub zażądać:inf': 9,
#              'rada:subst minister:subst określić:fin': 103,
#              'w:prep wypadek:subst towar:subst': 5,
#              'w:prep tym:conj sam:adj': 51,
#              'identyczny:adj lub:conj podobny:adj': 24,
#              'dla:prep który:adj ustalać:ppas': 20,
#              'który:adj ustalać:ppas być:fin': 20,
#              'ustalać:ppas być:fin wartość:subst': 21,
#              'być:fin wartość:subst celny:adj': 29,
#              'bezpośrednio:adv lub:conj pośrednio:adv': 52,
#              'w:prep oparcie:subst o:prep': 17,
#              'zgodnie:adv z:prep art:ign': 289,
#              'lub:conj podobny:adj towar:subst': 5,
#              'cena:subst faktycznie:adv zapłacić:ppas': 26,
#              'faktycznie:adv zapłacić:ppas lub:conj': 28,
#              'zapłacić:ppas lub:conj należny:adj': 34,
#              'lub:conj należny:adj za:qub': 12,
#              'za:qub wartość:subst celny:adj': 11,
#              'w:prep forma:subst pisemny:adj': 22,
#              'tym:conj sam:adj lub:conj': 10,
#              ...})

# %%
trigram_list = []
pmi_list = []
for trigram in counter_trigram:
    trigram_list.append(trigram)
    word_a, word_b, word_c = trigram.split(" ")
    pmi_list.append(log((counter_trigram[trigram])/len(counter_dict)) - log((counter_dict[word_a])/len(counter_dict)) - log((counter_dict[word_b])/len(counter_dict))- log((counter_dict[word_c])/len(counter_dict)))
df =pd.DataFrame({"trigram":trigram_list,"pmi":pmi_list})
trigram_clarina = df.sort_values(by="pmi",ascending=False)[:10].reset_index(drop=True) 
trigram_clarina
# Out:
#                                              trigram        pmi
# 0  reakcja:subst łańcuchowa:subst rozszczepienie:...  14.728727
# 1                  kurtka:subst anorak:subst etc:ign  13.671912
# 2                   piłka:subst nożny:adj uefa:subst  13.576047
# 3       finałowy:adj turniej:subst mistrzostwa:subst  13.380046
# 4                  milion:brev dolar:subst usa:subst  13.046793
# 5                 profil:subst zaufany:adj epuap:ign  13.030078
# 6          uniwersytet:subst maria:subst curie:subst  12.786583
# 7       rektyfikować:ppas zagęścić:ppas moszcz:subst  12.705206
# 8  łańcuchowa:subst rozszczepienie:subst jądrowy:adj  12.579416
# 9       turniej:subst mistrzostwa:subst europa:subst  12.547137

# %% [markdown]
# ### Create a table comparing the results for copora without and with tagging and lemmatization (separate table for bigrams and trigrams).

# %% [markdown]
# ##### Bigrams

# %%
pd.DataFrame({"spy_cy":bigram_morf['bigram'].values, "clarin":bigram_clarin['bigram'].values})
# Out:
#                       spy_cy                          clarin
# 0           nim następującym              eegcou:ign eok:ign
# 1         danej miejscowości           poin:ign formować:inf
# 2  ubezpieczenia społecznego          kalen:ign darzowym:ign
# 3     kwartale kalendarzowym             zajmo:ign wanym:ign
# 4             urząd skarbowy             mał:ign żonka:subst
# 5              górną granicę          fomar:ign roulunds:ign
# 6  rzeczypospolitej polskiej           ty:ppron12 godniu:ign
# 7         granicę pierwszego      uniemoż:ign liwiającej:ign
# 8      pierwszego przedziału          krętek:subst blady:adj
# 9       odrębnymi przepisami  promować:inf nowatorstwo:subst

# %% [markdown]
# #### trigram

# %%
pd.DataFrame({"spy_cy":trigram_morf['trigram'].values, "clarin":trigram_clarina['trigram'].values})
# Out:
#                                   spy_cy  \
# 0               górną granicę pierwszego
# 1  kwartale kalendarzowym poprzedzającym
# 2    kalendarzowym poprzedzającym termin
# 3      poprzedzającym termin waloryzacji
# 4                    po nim następującym
# 5                    nim następującym na
# 6         rozumieniu odrębnych przepisów
# 7                   następującym na cele
# 8                 zwrotu różnicy podatku
# 9                 z odrębnymi przepisami
#
#                                               clarin
# 0  reakcja:subst łańcuchowa:subst rozszczepienie:...
# 1                  kurtka:subst anorak:subst etc:ign
# 2                   piłka:subst nożny:adj uefa:subst
# 3       finałowy:adj turniej:subst mistrzostwa:subst
# 4                  milion:brev dolar:subst usa:subst
# 5                 profil:subst zaufany:adj epuap:ign
# 6          uniwersytet:subst maria:subst curie:subst
# 7       rektyfikować:ppas zagęścić:ppas moszcz:subst
# 8  łańcuchowa:subst rozszczepienie:subst jądrowy:adj
# 9       turniej:subst mistrzostwa:subst europa:subst

# %% [markdown]
# ### Answer the following questions:

# %% [markdown]
# #### Why do we have to filter the bigrams, rather than the token sequence?
# Aby zachować sens zdań. Jeżeli najpierw byśmy filtrowali tokeny, to potem powstałyby nam bigramy ze słów, które logicznie w zdaniu nie powinny być obok siebie np "Ala ma kota. Kot jest gruby". Jeżeli usuniemy kropke najpierw to otrzymamy bigram "kot kot", jeżeli będziemy filtrować bigramy to nie otrzymamy takiego połączenia, czego oczekujemy.
#
# #### Which method works better for the bigrams and which for the trigrams?
# Lepiej działa dla trigramów tokenizacja za pomocą clarin, ponieważ uwzględnia również odmiany wyrazów, ponieważ wszystkie człony sprowadzamy do formy podstawowej. Jednak dla bigramów nie zadziałał już najlepiej
#
# #### What types of expressions are discovered by the methods.
# Wyrażenie przyimkowe, epitety, nazwy własne np instytucji
#
#
# #### Can you devise a different type of filtering that would yield better results?
# nie
